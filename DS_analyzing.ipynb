# %%
import pandas as pd

pathfile = '/Users/corentin/Documents/ML/1_data/home-data-for-ml-course/test.csv'

df = pd.read_csv(pathfile)

df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df_analysis = pd.DataFrame( index = df.columns)

# %%
df_analysis['Missing values rate'] = 1 - df.count()/len(df)
df_analysis['Types'] = df.dtypes
df_analysis['Number of different values'] = [len(df[feature].unique())  for feature in df.columns]
df_analysis['Number of NaN values'] = [ df[features].isnull().sum() for feature in df.columns]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-609516e260bb> in <module>
#       2 df_analysis['Types'] = df.dtypes
#       3 df_analysis['Number of different values'] = [len(df[feature].unique())  for feature in df.columns]
# ----> 4 df_analysis['Number of NaN values'] = [ df[features].isnull().sum() for feature in df.columns]
#
# <ipython-input-39-609516e260bb> in <listcomp>(.0)
#       2 df_analysis['Types'] = df.dtypes
#       3 df_analysis['Number of different values'] = [len(df[feature].unique())  for feature in df.columns]
# ----> 4 df_analysis['Number of NaN values'] = [ df[features].isnull().sum() for feature in df.columns]
#
# NameError: name 'features' is not defined

# %%
df_analysis.head()
# Out:
#              Missing values rate    Types  Number of different values
# Id                      0.000000    int64                        1459
# MSSubClass              0.000000    int64                          16
# MSZoning                0.002742   object                           6
# LotFrontage             0.155586  float64                         116
# LotArea                 0.000000    int64                        1106

# %%
# !rm data_analysed.csv

df_analysis.to_csv('data_analysed.csv')
# Out:
# rm: data_analysed.csv: No such file or directory
